# %%
import polars as pl

valence_df = pl.read_excel('../Daten/ChildATale/ChildTale-A_Data_N80_Sentence_level.xlsx')

# %%
valence_df = valence_df.select(["Title_German", "Title_English", "Sentence", "Valence_Annotation"])
valence_df.head()
# Out:
# shape: (5, 4)
# ┌──────────────┬──────────────────┬───────────────────────────────────┬────────────────────┐
# │ Title_German ┆ Title_English    ┆ Sentence                          ┆ Valence_Annotation │
# │ ---          ┆ ---              ┆ ---                               ┆ ---                │
# │ str          ┆ str              ┆ str                               ┆ f64                │
# ╞══════════════╪══════════════════╪═══════════════════════════════════╪════════════════════╡
# │ Allerleirauh ┆ All-Kinds-Of-Fur ┆ Es war einmal ein König, der hat… ┆ 2.5                │
# │ Allerleirauh ┆ All-Kinds-Of-Fur ┆ Es geschah, dass sie krank lag, … ┆ -2.5               │
# │ Allerleirauh ┆ All-Kinds-Of-Fur ┆ Nachdem es ihr der König verspro… ┆ -3.0               │
# │ Allerleirauh ┆ All-Kinds-Of-Fur ┆ Der König war lange Zeit nicht z… ┆ -3.0               │
# │ Allerleirauh ┆ All-Kinds-Of-Fur ┆ Endlich sprachen seine Räte „es … ┆ -0.5               │
# ...

# %%
for row in valence_df["Sentence"]:
    print(row)
# Out:
# Es war einmal ein König, der hatte eine Frau mit goldenen Haaren, und sie war so schön, dass sich ihres Gleichen nicht mehr auf Erden fand.
# Es geschah, dass sie krank lag, und als sie fühlte dass sie bald sterben würde, rief sie den König und sprach „wenn du nach meinem Tode dich wieder vermählen willst, so nimm keine, die nicht eben so schön ist, als ich bin, und die nicht solche goldene Haare hat, wie ich habe; das musst du mir versprechen.“
# Nachdem es ihr der König versprochen hatte, tat sie die Augen zu und starb.
# Der König war lange Zeit nicht zu trösten und dachte nicht daran, eine zweite Frau zu nehmen.
# Endlich sprachen seine Räte „es geht nicht anders, der König muss sich wieder vermählen, damit wir eine Königin haben.“
# Nun wurden Boten weit und breit umhergeschickt, eine Braut zu suchen, die an Schönheit der verstorbenen Königin ganz gleich käme.
# ...

# %%
# from langchain_community.chat_models import ChatOpenAI
# from langchain_core.output_parsers import StrOutputParser
# from langchain.prompts import ChatPromptTemplate
# 
# 
# llm = ChatOpenAI(model_name="gpt-4-1106-preview", openai_api_key="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")
# output_parser = StrOutputParser()
# prompt = ChatPromptTemplate.from_messages([
#     ("system", "You are world class emotion annotator. You are given the task to rate a sentence by its valence. The valence scale ranges from -3 to 3. -3 means very negative, 0 means neutral and 3 means very positive. Q: Es war einmal ein König, der hatte eine Frau mit goldenen Haaren, und sie war so schön, dass sich ihres Gleichen nicht mehr auf Erden fand. \nA: 2"),
#     ("user", "{input}")
# ])

# %% [markdown]
# # GPT3.5

# %% [markdown]
# ## Valence - Zero Shot

# %%
from langchain_community.chat_models import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import ChatPromptTemplate

#gpt-4-1106-preview
llm = ChatOpenAI(model_name="gpt-3.5-turbo", openai_api_key="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")
output_parser = StrOutputParser()
prompt = ChatPromptTemplate.from_messages([
    ("system", """1. Bitte lesen Sie jeden einzelnen Satz und beurteilen Sie den emotionalen Gehalt des Satzes. 
    2. Auf der Valenzskala geben Sie bitte an, ob der Satz eher etwas Negatives, etwas Neutrales oder etwas Positives beschreibt. Bitte nutzen Sie die gesamte Skala von -3 bis +3, um möglichst genau anzugeben, ob der Satz z.B. nur leicht negativ (würde einem Wert von -1 entsprechen) oder sehr positiv ist (das würde z.B. einem Wert von +3 entsprechen). 
    3. Auf der zweiten Skala, der Arousal-Skala, geben Sie bitte an, ob der Satz eher etwas Ruhiges bzw. Entspanntes oder eher etwas Erregtes bzw. Aufgeregtes beschreibt. Bitte nutzen sie hier die Abstufungen von 1-5 um ihre Einschätzung abzugeben. Niedrige Werte drücken aus, dass der Satz eher etwas Ruhiges/Entspanntes beschreibt, höhere Werte drücken aus, dass der Satz eher etwas Erregtes/Aufgeregtes beschreibt. 
    Antworte in nur folgendem Format:
    Valenz: <-3 oder -2,5 oder -2 oder -1,5 oder -1 oder -0,5 oder 0 oder 0,5 oder 1 oder 1,5 oder 2 oder 2,5 oder 3>
    Arousal: <1 oder 1,5 oder 2 oder 2,5 oder 3 oder 3,5 oder 4 oder 4,5 oder 5>"""),
    ("user", "{input}")
])

# %%
import polars as pl

def custom_function(cell_value):
    return cell_value +2


data = {"a": [1, 2, 3], "b": [3, 4, 5]}
df = pl.DataFrame(data)
df.with_columns(df["b"].map_elements(custom_function).alias("c"))
# Out:
# /var/folders/_5/_my5m9wn6jd31c9yrxbr6t4c0000gn/T/ipykernel_39562/1562211805.py:9: PolarsInefficientMapWarning:
# Series.map_elements is significantly slower than the native series API.
# Only use if you absolutely CANNOT implement your logic otherwise.
# Replace this expression...
#   - s.map_elements(custom_function)
# with this one instead:
#   + s + 2
#
#   df.with_columns(df["b"].map_elements(custom_function).alias("c"))
# shape: (3, 3)
# ┌─────┬─────┬─────┐
# │ a   ┆ b   ┆ c   │
# │ --- ┆ --- ┆ --- │
# │ i64 ┆ i64 ┆ i64 │
# ╞═════╪═════╪═════╡
# │ 1   ┆ 3   ┆ 5   │
# │ 2   ┆ 4   ┆ 6   │
# │ 3   ┆ 5   ┆ 7   │
# └─────┴─────┴─────┘

# %%
def custom_function(cell_value):
    print("done")
    return "JIPPIE" + cell_value
df_with_custom_function = valence_df.with_columns([
    valence_df["Sentence"].map_elements(custom_function).alias("test")
])
df_with_custom_function
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
chain = prompt | llm | output_parser

# %%
from langchain.callbacks import get_openai_callback

def apply_chain(sentence):
    print("Done")
    return chain.invoke({"input": sentence})

with get_openai_callback() as cb:
    df_with_custom_function = valence_df.with_columns([
    valence_df["Sentence"].map_elements(apply_chain).alias("GPT3.5 Zero Shot")])
    print(f"Kosten für Valenz- und Arousalanalyse GPT 3.5 Zero Shot (USD): ${cb.total_cost}")

df_with_custom_function.write_csv("gpt35_zeroshot.csv")


# Liste zum Testen - ohne gleich 1000 API calls zu machen
# liste = []
# for x in range(3):
#     liste.append(apply_chain(valence_df.item(x, "Sentence")))
# liste
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ...

# %%
valence_df.head(10)

# %%
valence_df.write_csv("valence_arousal_gpt3_5.csv")

# %% [markdown]
# ## Valence Chain of Thought

# %%
from langchain_community.chat_models import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import ChatPromptTemplate

#gpt-4-1106-preview
llm = ChatOpenAI(model_name="gpt-3.5-turbo", openai_api_key="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")
output_parser = StrOutputParser()
prompt = ChatPromptTemplate.from_messages([
    ("system", """Du bist ein Experte im Annotieren von Emotionen. Befolge die folgende Annotationsrichtlinien und annotiere den gegebenen Text.
    ---
    1. Bitte lesen Sie jeden einzelnen Satz und beurteilen Sie den emotionalen Gehalt des Satzes. 
    2. Auf der Valenzskala geben Sie bitte an, ob der Satz eher etwas Negatives, etwas Neutrales oder etwas Positives beschreibt. Bitte nutzen Sie die gesamte Skala von -3 bis +3, um möglichst genau anzugeben, ob der Satz z.B. nur leicht negativ (würde einem Wert von -1 entsprechen) oder sehr positiv ist (das würde z.B. einem Wert von +3 entsprechen). 
    3. Auf der zweiten Skala, der Arousal-Skala, geben Sie bitte an, ob der Satz eher etwas Ruhiges bzw. Entspanntes oder eher etwas Erregtes bzw. Aufgeregtes beschreibt. Bitte nutzen sie hier die Abstufungen von 1-5 um ihre Einschätzung abzugeben. Niedrige Werte drücken aus, dass der Satz eher etwas Ruhiges/Entspanntes beschreibt, höhere Werte drücken aus, dass der Satz eher etwas Erregtes/Aufgeregtes beschreibt. 
    Antworte in nur folgendem Format:
    Valenz: <-3 oder -2,5 oder -2 oder -1,5 oder -1 oder -0,5 oder 0 oder 0,5 oder 1 oder 1,5 oder 2 oder 2,5 oder 3>
    Arousal: <1 oder 1,5 oder 2 oder 2,5 oder 3 oder 3,5 oder 4 oder 4,5 oder 5>
    ---
    Es war einmal ein König, der hatte eine Frau mit goldenen Haaren, und sie war so schön, dass sich ihres Gleichen nicht mehr auf Erden fand.
    Valenz: 2,5
    Arousal: 1,5
    
    Es geschah, dass sie krank lag, und als sie fühlte dass sie bald sterben würde, rief sie den König und sprach „wenn du nach meinem Tode dich wieder vermählen willst, so nimm keine, die nicht eben so schön ist, als ich bin, und die nicht solche goldene Haare hat, wie ich habe; das musst du mir versprechen.“
    Valenz: -2,5
    Arousal: 5
    
    Nachdem es ihr der König versprochen hatte, tat sie die Augen zu und starb.
    Valenz: -3
    Arousal: 5
    
    """),
    ("user", "{input}")
])

# %%
chain = prompt | llm | output_parser

# %%
from langchain.callbacks import get_openai_callback

def apply_chain(sentence):
    print("Done")
    return chain.invoke({"input": sentence})

with get_openai_callback() as cb:
    df_with_custom_function = valence_df.with_columns([
    valence_df["Sentence"].map_elements(apply_chain).alias("GPT3.5 Chain of Thought")])
    print(f"Kosten für Valenz- und Arousalanalyse GPT 3.5 Chain of Thought Shot (USD): ${cb.total_cost}")

df_with_custom_function.write_csv("gpt35_COT.csv")
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ...

# %% [markdown]
# # GPT4

# %% [markdown]
# ## Valence Zero Shot

# %%
from langchain_community.chat_models import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import ChatPromptTemplate

#gpt-4-1106-preview
llm = ChatOpenAI(model_name="gpt-4-1106-preview", openai_api_key="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")
output_parser = StrOutputParser()
prompt = ChatPromptTemplate.from_messages([
    ("system", """1. Bitte lesen Sie jeden einzelnen Satz und beurteilen Sie den emotionalen Gehalt des Satzes. 
    2. Auf der Valenzskala geben Sie bitte an, ob der Satz eher etwas Negatives, etwas Neutrales oder etwas Positives beschreibt. Bitte nutzen Sie die gesamte Skala von -3 bis +3, um möglichst genau anzugeben, ob der Satz z.B. nur leicht negativ (würde einem Wert von -1 entsprechen) oder sehr positiv ist (das würde z.B. einem Wert von +3 entsprechen). 
    3. Auf der zweiten Skala, der Arousal-Skala, geben Sie bitte an, ob der Satz eher etwas Ruhiges bzw. Entspanntes oder eher etwas Erregtes bzw. Aufgeregtes beschreibt. Bitte nutzen sie hier die Abstufungen von 1-5 um ihre Einschätzung abzugeben. Niedrige Werte drücken aus, dass der Satz eher etwas Ruhiges/Entspanntes beschreibt, höhere Werte drücken aus, dass der Satz eher etwas Erregtes/Aufgeregtes beschreibt. 
    Antworte in nur folgendem Format:
    Valenz: <-3 oder -2,5 oder -2 oder -1,5 oder -1 oder -0,5 oder 0 oder 0,5 oder 1 oder 1,5 oder 2 oder 2,5 oder 3>
    Arousal: <1 oder 1,5 oder 2 oder 2,5 oder 3 oder 3,5 oder 4 oder 4,5 oder 5>"""),
    ("user", "{input}")
])

# %%
chain = prompt | llm | output_parser

# %%
from langchain.callbacks import get_openai_callback

def apply_chain(sentence):
    print("Done")
    return chain.invoke({"input": sentence})

with get_openai_callback() as cb:
    df_with_custom_function = valence_df.with_columns([
    valence_df["Sentence"].map_elements(apply_chain).alias("GPT4 Zero Shot")])
    print(f"Kosten für Valenz- und Arousalanalyse GPT4 Zero Shot (USD): ${cb.total_cost}")

df_with_custom_function.write_csv("gpt4_zeroshot.csv")


# Liste zum Testen - ohne gleich 1000 API calls zu machen
# liste = []
# for x in range(3):
#     liste.append(apply_chain(valence_df.item(x, "Sentence")))
# liste
# Out:
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# Done
# ...

# %% [markdown]
# ## Valence Chain of Thought

# %%
from langchain_community.chat_models import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import ChatPromptTemplate

#gpt-4-1106-preview
llm = ChatOpenAI(model_name="gpt-4-1106-preview", openai_api_key="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")
output_parser = StrOutputParser()
prompt = ChatPromptTemplate.from_messages([
    ("system", """Du bist ein Experte im Annotieren von Emotionen. Befolge die folgende Annotationsrichtlinien und annotiere den gegebenen Text.
    ---
    1. Bitte lesen Sie jeden einzelnen Satz und beurteilen Sie den emotionalen Gehalt des Satzes. 
    2. Auf der Valenzskala geben Sie bitte an, ob der Satz eher etwas Negatives, etwas Neutrales oder etwas Positives beschreibt. Bitte nutzen Sie die gesamte Skala von -3 bis +3, um möglichst genau anzugeben, ob der Satz z.B. nur leicht negativ (würde einem Wert von -1 entsprechen) oder sehr positiv ist (das würde z.B. einem Wert von +3 entsprechen). 
    3. Auf der zweiten Skala, der Arousal-Skala, geben Sie bitte an, ob der Satz eher etwas Ruhiges bzw. Entspanntes oder eher etwas Erregtes bzw. Aufgeregtes beschreibt. Bitte nutzen sie hier die Abstufungen von 1-5 um ihre Einschätzung abzugeben. Niedrige Werte drücken aus, dass der Satz eher etwas Ruhiges/Entspanntes beschreibt, höhere Werte drücken aus, dass der Satz eher etwas Erregtes/Aufgeregtes beschreibt. 
    Antworte in nur folgendem Format:
    Valenz: <-3 oder -2,5 oder -2 oder -1,5 oder -1 oder -0,5 oder 0 oder 0,5 oder 1 oder 1,5 oder 2 oder 2,5 oder 3>
    Arousal: <1 oder 1,5 oder 2 oder 2,5 oder 3 oder 3,5 oder 4 oder 4,5 oder 5>
    ---
    Es war einmal ein König, der hatte eine Frau mit goldenen Haaren, und sie war so schön, dass sich ihres Gleichen nicht mehr auf Erden fand.
    Valenz: 2,5
    Arousal: 1,5
    
    Es geschah, dass sie krank lag, und als sie fühlte dass sie bald sterben würde, rief sie den König und sprach „wenn du nach meinem Tode dich wieder vermählen willst, so nimm keine, die nicht eben so schön ist, als ich bin, und die nicht solche goldene Haare hat, wie ich habe; das musst du mir versprechen.“
    Valenz: -2,5
    Arousal: 5
    
    Nachdem es ihr der König versprochen hatte, tat sie die Augen zu und starb.
    Valenz: -3
    Arousal: 5
    
    """),
    ("user", "{input}")
])

# %%
chain = prompt | llm | output_parser

# %%
from langchain.callbacks import get_openai_callback

def apply_chain(sentence):
    print("Done")
    return chain.invoke({"input": sentence})

with get_openai_callback() as cb:
    df_with_custom_function = valence_df.with_columns([
    valence_df["Sentence"].map_elements(apply_chain).alias("GPT4 Chain of Thought")])
    print(f"Kosten für Valenz- und Arousalanalyse GPT4 Chain of Thought Shot (USD): ${cb.total_cost}")

df_with_custom_function.write_csv("gpt4_COT.csv")
